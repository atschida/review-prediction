# %%
import matplotlib
matplotlib.use('Agg')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Andy\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Andy\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Andy\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Andy\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Andy\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
def clean(review):
    if (isNaN(review)):
        return ''
    review = re.sub("[^a-zA-z]", ' ', review)
    review = review.lower()
    review = review.split()
    ps = PorterStemmer()
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = " ".join(review)
    return review

def isNaN(string):
    return string != string

# %%
train_df = pd.read_csv('train_raw.csv', index_col=0)
train_df['positive'] = train_df['star_rating'].apply(lambda x: 1 if x > 3 else 0)
train_df['clean_review'] = train_df['review_body'].apply(clean)
train_df.head()
# Out:
#        marketplace  customer_id       review_id  product_id  product_parent  \
# 267779          US      3387522  R2JEMKCQT9QTVM  B008SBZD5U       150118808
# 267796          US     15137367  R3IM5TXYMA7DCQ  B00IXMF5CU       292308774
# 267818          US     15137367   R2PFXXB4EP23B  B00EM5UFEK       461081395
# 267871          US      4354770  R1A9DB178PFXLH  B004OPYLTS       245894499
# 267892          US      6698937  R1RS2GAXENP9LF  B00BGA9X9W       943154724
#
#                                             product_title product_category  \
# 267779                        Kingdom Hearts HD 1.5 Remix      Video Games
# 267796                                Terraria - Xbox 360      Video Games
# 267818                  Plants vs. Zombies Garden Warfare      Video Games
# 267871                              Fishdom - Nintendo DS      Video Games
# 267892  DualShock 4 Wireless Controller for PlayStatio...      Video Games
#
# ...

# %%
[item for l in train_df[train_df.customer_id == 3387522].clean_review.apply(lambda x: x.split()) for item in l]
# Out:
# ['pretti',
#  'good',
#  'game',
#  'came',
#  'time',
#  'think',
#  'wait',
#  'anoth',
#  'year',
#  'two',
#  'combo',
#  'set',
#  'ps',
#  'releas',
#  'usual',
#  'aliv',
#  'pretti',
#  'good',
#  'phan',
#  'consid',
#  'pull',
#  'old',
#  'unit',
#  'basic',
#  'get',
#  'unit',
#  'alreadi',
#  'use',
#  'bought',
#  'new',
#  'crack',
#  'edg',
#  'alright',
#  'middl',
#  'probabl',
#  'ship',
#  'damag',
#  'okay',
#  'consid',
#  'littl',
#  'charg',
#  'got',
#  'mean',
#  'use',
#  'aftermarket',
#  'charger',
#  'that',
#  'cheap',
#  'work']

# %%
myId = 3387522
words = [item for l in train_df.query('customer_id == {} & positive == 1'.format(myId)).clean_review.apply(lambda x: x.split()) for item in l]
{w : words.count(w) for w in words}
# Out:
# {'pretti': 2,
#  'good': 2,
#  'game': 1,
#  'came': 1,
#  'time': 1,
#  'think': 1,
#  'wait': 1,
#  'anoth': 1,
#  'year': 1,
#  'two': 1,
#  'combo': 1,
#  'set': 1,
#  'ps': 1,
#  'releas': 1,
#  'usual': 1,
#  'aliv': 1,
#  'phan': 1,
#  'consid': 1,
#  'pull': 1,
#  'old': 1,
#  'unit': 2,
#  'basic': 1,
#  'get': 1,
#  'alreadi': 1,
#  'use': 1,
#  'aftermarket': 1,
#  'charger': 1,
#  'that': 1,
#  'cheap': 1,
#  'work': 1}
