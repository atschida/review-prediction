# %%
import pandas as pd

# %%
df = pd.read_csv('data/amazon_reviews_us_Musical_Instruments_v1_00.tsv', sep='\t', error_bad_lines=False)
df.positive = df.star_rating.apply(lambda rating: 1 if rating > 3 else 0)
df.head()
# Out:
# b'Skipping line 5782: expected 15 fields, saw 22\nSkipping line 31979: expected 15 fields, saw 22\nSkipping line 32408: expected 15 fields, saw 22\nSkipping line 45709: expected 15 fields, saw 22\nSkipping line 64585: expected 15 fields, saw 22\n'
# b'Skipping line 115742: expected 15 fields, saw 22\nSkipping line 125537: expected 15 fields, saw 22\nSkipping line 127580: expected 15 fields, saw 22\nSkipping line 128696: expected 15 fields, saw 22\n'
# b'Skipping line 143851: expected 15 fields, saw 22\nSkipping line 147069: expected 15 fields, saw 22\nSkipping line 149233: expected 15 fields, saw 22\nSkipping line 167536: expected 15 fields, saw 22\nSkipping line 168535: expected 15 fields, saw 22\nSkipping line 171659: expected 15 fields, saw 22\nSkipping line 184533: expected 15 fields, saw 22\nSkipping line 184624: expected 15 fields, saw 22\nSkipping line 184908: expected 15 fields, saw 22\n'
# b'Skipping line 219150: expected 15 fields, saw 22\nSkipping line 223178: expected 15 fields, saw 22\nSkipping line 234333: expected 15 fields, saw 22\nSkipping line 256242: expected 15 fields, saw 22\n'
# b'Skipping line 268157: expected 15 fields, saw 22\nSkipping line 276191: expected 15 fields, saw 22\nSkipping line 277091: expected 15 fields, saw 22\nSkipping line 288516: expected 15 fields, saw 22\nSkipping line 289901: expected 15 fields, saw 22\nSkipping line 292922: expected 15 fields, saw 22\nSkipping line 308964: expected 15 fields, saw 22\nSkipping line 325233: expected 15 fields, saw 22\n'
# b'Skipping line 354051: expected 15 fields, saw 22\nSkipping line 360552: expected 15 fields, saw 22\nSkipping line 362489: expected 15 fields, saw 22\nSkipping line 383798: expected 15 fields, saw 22\nSkipping line 392390: expected 15 fields, saw 22\n'
# b'Skipping line 456105: expected 15 fields, saw 22\n'
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     45610553   RMDCHWD0Y5OZ9  B00HH62VB6       618218723
# 1          US     14640079   RZSL0BALIYUNU  B003LRN53I       986692292
# 2          US      6111003   RIZR67JKUDBI0  B0006VMBHI       603261968
# 3          US      1546619  R27HL570VNL85F  B002B55TRG       575084461
# 4          US     12222213  R34EBU9QDWJ1GD  B00N1YPXW2       165236328
#
#                                        product_title     product_category  \
# 0  AGPtek® 10 Isolated Output 9V 12V 18V Guitar P...  Musical Instruments
# 1         Sennheiser HD203 Closed-Back DJ Headphones  Musical Instruments
# 2                   AudioQuest LP record clean brush  Musical Instruments
# 3      Hohner Inc. 560BX-BF Special Twenty Harmonica  Musical Instruments
# 4        Blue Yeti USB Microphone - Blackout Edition  Musical Instruments
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0            3              0            1    N                 N
# 1            5              0            0    N                 Y
# 2            3              0            1    N                 Y
# 3            5              0            0    N                 Y
# 4            5              0            0    N                 Y
#
#                                      review_headline  \
# 0                                        Three Stars
# 1                                         Five Stars
# 2                                        Three Stars
# 3  I purchase these for a friend in return for pl...
# 4                                         Five Stars
#
#                                          review_body review_date
# 0        Works very good, but induces ALOT of noise.  2015-08-31
# 1             Nice headphones at a reasonable price.  2015-08-31
# 2                       removes dust. does not clean  2015-08-31
# 3  I purchase these for a friend in return for pl...  2015-08-31
# 4                            This is an awesome mic!  2015-08-31

# %%
df.star_rating.describe()
# Out:
# count    904004.000000
# mean          4.251045
# std           1.216422
# min           1.000000
# 25%           4.000000
# 50%           5.000000
# 75%           5.000000
# max           5.000000
# Name: star_rating, dtype: float64

# %%
df.groupby(df.customer_id).mean()
# Out:
#              product_parent  star_rating  helpful_votes  total_votes
# customer_id
# 10113            25346839.0          5.0            0.0          0.0
# 10136           889395489.0          5.0            0.0          0.0
# 10154           710183466.0          5.0            1.0          1.0
# 10271           405110012.0          5.0            1.0          2.0
# 10299           781341356.0          5.0            0.0          0.0
# ...                     ...          ...            ...          ...
# 53096456        894875914.0          2.0           25.0         27.0
# 53096471        642007244.0          5.0            2.0          2.0
# 53096533        685106004.0          5.0            0.0          0.0
# 53096561        375542897.0          4.0           48.0         52.0
# 53096564        977885804.0          3.0            6.0          7.0
#
# [572785 rows x 4 columns]

# %%
df.groupby(df.product_id).first()
# Out:
#            marketplace  customer_id       review_id  product_parent  \
# product_id
# 0014110024          US     52913042  R2E8CBLCEGKFTC       503276747
# 0041291905          US     12290158  R3VXJSANTBOFAR        41397542
# 0046197141          US     30925122  R35BMROOEYYR6Z       848687463
# 0193757710          US      6518553   RX7C35P5K3RBK       846060745
# 0205822908          US     32583180  R3FBUHCZ19Z08O       624769486
# ...                ...          ...             ...             ...
# B014GZ52IO          US      6291789  R104XCXQMYCYHB       197082916
# B014K2S348          US     24740219  R3FL2NTLFUSPTQ       865024902
# B01IBI8F86          US     51390754  R33MJIKFETI6CN       345627821
# B01IBI8HKC          US     50802030  R1BXDULUVN67X6       345627821
# B0716RFGH8          US     50055011   RJH8LH8LTM50M       315917274
#
#                                                 product_title  \
# product_id
# 0014110024                             Recital Training Vol.1
# 0041291905  Hal Leonard Vivaldi Four Seasons for Piano (Or...
# 0046197141                  Aria for Alto Saxophone and Piano
# 0193757710  Suite for Organ (including the Trumpet Volunta...
# 0205822908  Los Cabos Drumsticks - Los Cabos 5A Intense Hi...
# ...                                                       ...
# B014GZ52IO  Amdirect Drum Soft Padded Seat Stool Stand Dru...
# B014K2S348  AKG 2015 NEWEST MODEL M220 PRO STYLIST PROFESS...
# B01IBI8F86       Planet Waves NS Artist Capo, Metallic Bronze
# B01IBI8HKC       Planet Waves NS Artist Capo, Metallic Bronze
# B0716RFGH8   Ibanez RG Prestige Series RG655M Electric Guitar
#
#                product_category  star_rating  helpful_votes  total_votes vine  \
# product_id
# 0014110024  Musical Instruments            5              2            2    N
# 0041291905  Musical Instruments            5              0            0    N
# 0046197141  Musical Instruments            5              1            1    N
# 0193757710  Musical Instruments            5              0            0    N
# 0205822908  Musical Instruments            5              0            0    N
# ...                         ...          ...            ...          ...  ...
# B014GZ52IO  Musical Instruments            5              1            1    N
# B014K2S348  Musical Instruments            5             33           37    N
# B01IBI8F86  Musical Instruments            5              1            1    Y
# B01IBI8HKC  Musical Instruments            4              0            0    Y
# B0716RFGH8  Musical Instruments            5              0            0    N
#
#            verified_purchase  \
# product_id
# 0014110024                 Y
# 0041291905                 Y
# 0046197141                 Y
# 0193757710                 Y
# 0205822908                 N
# ...                      ...
# B014GZ52IO                 N
# B014K2S348                 N
# B01IBI8F86                 Y
# B01IBI8HKC                 N
# B0716RFGH8                 N
#
#                                               review_headline  \
# product_id
# 0014110024              Excellent Supplement to Suzuki book 4
# 0041291905                            Vivalldi's Four Seasons
# 0046197141  The is a beautiful piece. Don't be deceived - ...
# 0193757710                                       Great music!
# 0205822908                                            Amazing
# ...                                                       ...
# B014GZ52IO              Shipping was fast and items are great
# B014K2S348  Might need an Amp, but absolutely excellent wi...
# B01IBI8F86          Planet Waves NS Artist Capo Metallic Grey
# B01IBI8HKC                       Break the mold, not the bank
# B0716RFGH8                              Best I've Ever Played
#
#                                                   review_body review_date
# product_id
# 0014110024  This is an excellent adjunct to Suzuki book 4....  2013-03-08
# 0041291905  This is and excellent edition and perfectly tr...  2013-10-14
# 0046197141  The is a beautiful piece.  Don't be deceived -...  2015-04-18
# 0193757710  Great music; fabulous arrangement! It is too b...  2013-11-05
# 0205822908  Simply amazing, well balanced, longer but not ...  2013-08-16
# ...                                                       ...         ...
# B014GZ52IO  I bought 6 stool chairs and I love them they a...  2015-08-28
# B014K2S348  I picked these headphones up at Massdrop about...  2015-08-30
# B01IBI8F86  Lightweight and easy to put on and take off wi...  2014-05-05
# B01IBI8HKC  This is a solid capo.  There is no fret buzz w...  2014-04-29
# B0716RFGH8  RG655M in Cobalt Blue: I bought the guitar ove...  2015-07-11
#
# [123284 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split
numerical_features = df[['customer_id', 'product_parent', 'helpful_votes', 'total_votes', 'vine', 'verified_purchase']]
numerical_features.vine = numerical_features.vine.apply(lambda str: 1 if str == 'Y' else 0)
numerical_features.verified_purchase = numerical_features.verified_purchase.apply(lambda str: 1 if str == 'Y' else 0)

X_train, X_test, y_train, y_test = train_test_split(numerical_features, df.positive)

X_train.head()
# Out:
#         customer_id  product_parent  helpful_votes  total_votes  vine  \
# 282844     52106485       168428822              3            4     0
# 656028     32691595       204180843              3            3     0
# 118609     44635875       251144791              0            0     0
# 215707      3838432       991924617              0            0     0
# 242600     48989150         5151706              0            0     0
#
#         verified_purchase
# 282844                  0
# 656028                  1
# 118609                  1
# 215707                  1
# 242600                  1
